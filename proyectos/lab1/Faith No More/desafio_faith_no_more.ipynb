# %% [markdown]
# # Faith No More: Data Cleaning and Preparation
#
# ## 🧩 Desafío: Limpieza básica de la columna `country`
#
# ### 🎯 Objetivo
# Practicar técnicas simples de **limpieza de texto** y **manejo de valores nulos** en una columna categórica.
#
# ### 📄 Descripción
# Trabajaremos con el dataset **Netflix Movies and TV Shows**, disponible en:
#
# `./datasets/Alumnos/Equipo Faith No More/Netflix Movies and TV Shows/netflix\_titles.csv`
#
# En la columna `country` se observan los siguientes problemas:
# - Algunos valores están escritos en minúsculas, otros en mayúsculas o combinados.
# - Existen valores faltantes.
#
# ### 🛠️ Tareas
# 1. Reemplazar los valores nulos de la columna `country` por el texto `"UNKNOWN"`.
# 2. Estandarizar todos los valores de `country` a **mayúsculas**.
# 3. Contar cuántos títulos provienen de `"UNITED STATES"`.
#
# ### ❓ Pregunta
# Después de aplicar las transformaciones, ¿cuántos títulos en total provienen de `"UNITED STATES"`?
#
# ### 💡 Hint
# Podés utilizar métodos como:
# - `.fillna()`
# - `.str.upper()`
# - `.value_counts()`

# %%
# ~~~ Te ayudamos a dar los pasos inciales: ~~~#
# ~~~ Importación de librería pandas y del dataset. ~~~ #

import pandas as pd

direccion = r"../../../datasets/Alumnos/Equipo Faith No More/Netflix Movies and TV Shows/netflix_titles.csv"

df = pd.read_csv(direccion)

# Verificamos que el archivo se haya cargado correctamente.
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# None
