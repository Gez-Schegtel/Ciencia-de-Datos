# %% [markdown]
# # 🔁 Retrospectiva - Ciencia de Datos 2025
#
# Este notebook resume las observaciones realizadas en la retrospectiva grupal y propone respuestas o acciones concretas para cada eje.
#
# ---
#
# ## ➕ Para Agregar
#
# | Tema | Acción Propuesta |
# |------|------------------|
# | Complementar Expos con contenidos | Es muy buena, ya implementando. |
# | Material opcional | Seguimos agregando. |
# | Mejorar estructura GitHub | Lo tomamos para el año que viene. |
# | Contenido previo a expos | ¿?. |
# | Feedback en Discord | Aún me falta que comenten más... |
#
# ---
#
# ## ➖ Para Quitar
#
# | Tema | Acción Propuesta |
# |------|------------------|
# | readme.AI o mejorar | Esto fue generado con IA :-) . Mejorar QA. |
# | Inglés (en exceso) | Ya saben lo que pienso. Quedo a disposición para aclarar cualquier duda. Si encuentran
# material en español análogo, se puede utilizar. En 90% del material que usamos solo está en inglés. |
#
# ---
#
# ## 🔁 Para Mantener
#
# | Tema | Comentario |
# |------|------------|
# | Múltiples fuentes | Excelente práctica. Se continuará con referencias mixtas (papers, videos, docs, libros). |
# | Discord | Se mantiene como canal oficial para consultas, debates y feedback. |
# | Inglés | Se mantiene el uso, pero con criterio (ver arriba). |
# | GitHub | Se mantiene como base central del curso. |
# | Expos | Continúan como metodología activa de evaluación formativa. |
# | Retros | Se repiten al final de cada unidad para ajustar el rumbo. |
#
# ---
#
# ## ❓ Otros Temas (a Clarificar)
#
# | Tema | Propuesta |
# |------|----------|
# | Obligatorio vs. opcional.txt | Bien, se han etiquetado todos los contenidos con esta info. |
#
# ---
#
# > 🧠 *Gracias por el compromiso y las sugerencias. Este curso lo construimos entre todos/as.* 💪
