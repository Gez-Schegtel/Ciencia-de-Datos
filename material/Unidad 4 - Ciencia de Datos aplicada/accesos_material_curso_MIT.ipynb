# %% [markdown]
# ## Material curso MIT
#
# 1.1 [OBLIGATORIO] What is unsupervised learning
# https://drive.google.com/file/d/1043eALzeh_yWYZdsSldmUAg1HR2Hxo99/view?usp=sharing
#
# 1.2 [OBLIGATORIO] Tools and Applications & how th
# https://drive.google.com/file/d/1bbvjZVU5g0dOZ13y4lBaB45ZQl2HBFn0/view?usp=sharing
#
# 1.3 [OBLIGATORIO] What is Clustering
# https://drive.google.com/file/d/1zntxJwC-gJgByJGG8hp5V9uZObkfinjX/view?usp=sharing
#
# 1.4 [OBLIGATORIO] When to use Clustering
# https://drive.google.com/file/d/1r04MzyEVT73EZvk0yewdr-1mcU3zr_xN/view?usp=sharing
#
# 1.5 [OPCIONAL] K-means Preliminaries
# https://drive.google.com/file/d/1DwzcmGFgmgMOqdH_vzbr-fSauNPBEkV3/view?usp=sharing
#
# 1.6 [OPCIONAL] The K-means Algorithm
# https://drive.google.com/file/d/1vUFkmbS5GaEfVb31sppdLs_qMDdMRo4e/view?usp=sharing
#
# 1.7 [OPCIONAL] How to Evaluate Clustering.mp4
# https://drive.google.com/file/d/1q592g8KHT3qHclAaAX-LJwu4diaQ5SJh/view?usp=sharing
#
#
#
# 6.1 [OBLIGATORIO] Introduction.mp4
# https://drive.google.com/file/d/14KgE-rKybes04DKV0IWhY37Ia9wZRqUN/view?usp=sharing
#
# 6.2 [OBLIGATORIO] Defining Outcomes to Predict
# https://drive.google.com/file/d/16rGefVhvO6131e_9IXcW1OHdvPjj-7Ao/view?usp=sharing
#
# 6.3 [OBLIGATORIO] Searching for Training Examples
# https://drive.google.com/file/d/11rtGjy2Iy3LTLyv8mZPMsMj8cMyqHufk/view?usp=sharing
#
# 6.4 [OBLIGATORIO] Assembling Data for Feature Eng
# https://drive.google.com/file/d/1BWytBtVq-kST6d3EI2MSZ_Jz8GsUm3T-/view?usp=sharing
#
# 6.5 [OBLIGATORIO] Feature Engineering - Introduct
# https://drive.google.com/file/d/1g3RBLHK7i_09Jpti1P1gMBR4Mcs6If7J/view?usp=sharing
#
# 6.6 [OBLIGATORIO] Feature Types
# https://drive.google.com/file/d/1Q3ZYS4XP2TJAumniQ97u84xLSU-KYvKR/view?usp=sharing
#
#
#
#
# 4.1.1 [OPCIONAL] What Does a Recommendation Sy
# https://drive.google.com/file/d/1D7ph3lZrnsFoMkvt819rx-BcMsd0MGSV/view?usp=sharing
#
# 4.1.2 [OPCIONAL] What Does a Recommendation Sy
# https://drive.google.com/file/d/1OsiNKalLUHReDuVklmED6fu4c-siB9Yg/view?usp=sharing
#
# 4.1.3 [OPCIONAL] What does a recommendation sy
# https://drive.google.com/file/d/1i9xXjZuilVZGGneVwlX7ZYw6en8R9sbH/view?usp=sharing
#
# 4.2.1 [OPCIONAL] So What is the Recommendation
# https://drive.google.com/file/d/1gvJ1_cXmvvfk1c8tnXeVBlBca6gm_5OK/view?usp=sharing
#
# 4.2.2 [OPCIONAL] So What is the Recommendation
# https://drive.google.com/file/d/1XN73djeHTqvDayRuiFuLs3nymxz8no3L/view?usp=sharing
#
# 4.3.1 [OPCIONAL] Recommendation Algorithm 101 - 1
# https://drive.google.com/file/d/1VL0OetHAvjkArZ_reUXJ6tqssHz7g1Gr/view?usp=sharing
#
# 4.3.1 [OPCIONAL] Recommendation Algorithm 101 - 2
# https://drive.google.com/file/d/1LMTq7Z3u7iOiCTrbtadGTOuaa8D7CubN/view?usp=sharing
#
# 4.3.1 [OPCIONAL] Recommendation Algorithm 101 - 3
# https://drive.google.com/file/d/1mRlAUuKELahW6jBXcpYyX_Mb1QTju2qx/view?usp=sharing
