# %% [markdown]
# # 🔬 Laboratorio de Feature Engineering
#
# ## 🧠 Consigna
#
# Selecciona **una receta** de cualquiera de los capítulos del libro *Python Feature Engineering Cookbook*. Tu objetivo será preparar una presentación de menos de **10 minutos** explicando:
#
# 1. ¿De qué trata la receta elegida?
# 2. ¿Por qué es útil en proyectos de ciencia de datos?
# 3. ¿Cómo se aplica con datos propios? (No se permite reutilizar los datasets del libro)
#
# ## 🎯 Entregable
#
# Debes crear una **presentación clara y breve** que incluya:
#
# - El nombre de la receta y el capítulo donde se encuentra
# - Un ejemplo funcional con un dataset propio
# - Visualizaciones o salidas relevantes (si aplica)
# - Tiempo total de exposición: **Máximo 10 minutos**
#
# ## 📊 Material
#
# El libro se encuentra disponible en el repo el Material / Unidad 4 / con el nombre de "Galli - Python Feature Engineering Cookbook.pdf"
#
#
# ¡Buena suerte y que la creatividad esté contigo! 💡
